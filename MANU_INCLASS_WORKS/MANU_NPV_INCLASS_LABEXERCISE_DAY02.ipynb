# %% [markdown]
# # IN CLASS LAB EXERCISE - 02

# %% [markdown]
# (Kaggle Automobile Dataset)
#
#  We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle.
#
# **INCLASS LAB EXERCISE** answer below question. Load pandas as pd and upload the Automobile.csv file as auto

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %% [markdown]
# --------

# %%
import pandas as pd
import os

# %% [markdown]
# **Q.no(1). Check the head of the DataFrame.**

# %%
#Ans(1):
#Type Your Code Here
os.chdir('C:\\Users\\DILIP\\Downloads')

# %%
auto=pd.read_csv('automobile.csv')
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# ------------------

# %% [markdown]
# **Q.no(2). How many rows and columns are there.**

# %%
#Ans(2):
#Type Your Code Here
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# symboling              201 non-null int64
# normalized_losses      201 non-null int64
# make                   201 non-null object
# fuel_type              201 non-null object
# aspiration             201 non-null object
# number_of_doors        201 non-null object
# body_style             201 non-null object
# drive_wheels           201 non-null object
# engine_location        201 non-null object
# wheel_base             201 non-null float64
# length                 201 non-null float64
# width                  201 non-null float64
# height                 201 non-null float64
# curb_weight            201 non-null int64
# engine_type            201 non-null object
# number_of_cylinders    201 non-null object
# engine_size            201 non-null int64
# fuel_system            201 non-null object
# bore                   201 non-null float64
# ...

# %% [markdown]
# ---------------------

# %% [markdown]
# **Q.no(3). What is the average Price of all cars in the dataset.**

# %%
#Ans(3):
#Type Your Code Here
auto['price'].mean()
# Out:
# 13207.129353233831

# %% [markdown]
# -------------------------------

# %% [markdown]
# **Q.no(4). Which is the cheapest make and costliest make of car in the lot.**

# %%
#Ans(4):
#Type Your Code Here
auto[auto['price']==auto['price'].max()]  #costiliest car
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 71          304         mpfi   3.8    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 71      4500       14           16  45400
#
# [1 rows x 26 columns]

# %%
#Ans(4):
#Type Your Code Here
auto[auto['price']==auto['price'].min()]  #cheapest car
# Out:
#      symboling  normalized_losses    make fuel_type aspiration  \
# 134          2                 83  subaru       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 134             two  hatchback          fwd           front        93.7  ...
#
#      engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 134           97         2bbl  3.62    2.36               9.0         69
#
#      peak_rpm city_mpg  highway_mpg  price
# 134      4900       31           36   5118
#
# [1 rows x 26 columns]

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(5). How many cars have horsepower greater than 100.**

# %%
#Ans(5):
#Type Your Code Here
auto[auto['horsepower']>100].count()
# Out:
# symboling              90
# normalized_losses      90
# make                   90
# fuel_type              90
# aspiration             90
# number_of_doors        90
# body_style             90
# drive_wheels           90
# engine_location        90
# wheel_base             90
# length                 90
# width                  90
# height                 90
# curb_weight            90
# engine_type            90
# number_of_cylinders    90
# engine_size            90
# fuel_system            90
# bore                   90
# stroke                 90
# compression_ratio      90
# horsepower             90
# peak_rpm               90
# city_mpg               90
# highway_mpg            90
# price                  90
# dtype: int64

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(6). How many hatchback cars are in the dataset .**

# %%
#Ans(6):
#Type Your Code Here
auto[auto['body_style'] == 'hatchback'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 2 to 186
# Data columns (total 26 columns):
# symboling              68 non-null int64
# normalized_losses      68 non-null int64
# make                   68 non-null object
# fuel_type              68 non-null object
# aspiration             68 non-null object
# number_of_doors        68 non-null object
# body_style             68 non-null object
# drive_wheels           68 non-null object
# engine_location        68 non-null object
# wheel_base             68 non-null float64
# length                 68 non-null float64
# width                  68 non-null float64
# height                 68 non-null float64
# curb_weight            68 non-null int64
# engine_type            68 non-null object
# number_of_cylinders    68 non-null object
# engine_size            68 non-null int64
# fuel_system            68 non-null object
# bore                   68 non-null float64
# stroke                 68 non-null float64
# ...

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(7). What are the 3 most commonly found cars in the dataset?**

# %%
#Ans(7):
#Type Your Code Here
auto['make'].value_counts().head(3)
# Out:
# toyota    32
# nissan    18
# mazda     17
# Name: make, dtype: int64

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(8). Someone purchased a car for 7099, what is the make of the car?**

# %%
#Ans(8):
#Type Your Code Her
auto[auto['price']==7099]['make']
# Out:
# 87    nissan
# Name: make, dtype: object

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(9). Which cars are priced greater than 40000.**

# %%
#Ans(9):
#Type Your Code Her
auto[auto['price']>40000]
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(10). Which are the cars that are both a sedan and priced less than 7000?**

# %%
#Ans(10):
#Type Your Code Her
auto[(auto['body_style']=='sedan') & (auto['price'] < 7000)]
# Out:
#      symboling  normalized_losses        make fuel_type aspiration  \
# 19           0                 81   chevrolet       gas        std
# 24           1                148       dodge       gas        std
# 42           0                110       isuzu       gas        std
# 50           1                113       mazda       gas        std
# 82           1                125  mitsubishi       gas        std
# 86           1                128      nissan       gas        std
# 88           1                128      nissan       gas        std
# 89           1                122      nissan       gas        std
# 118          1                154    plymouth       gas        std
# 152          0                 91      toyota       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 19             four      sedan          fwd           front        94.5  ...
# ...

# %% [markdown]
# -------

# %% [markdown]
# **Q.no(11) Show the prices of cars in ascending order.**

# %%
auto.sort_values(by='price') ## default is ascending order.
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 134          2                 83         subaru       gas        std
# 17           2                121      chevrolet       gas        std
# 47           1                104          mazda       gas        std
# 146          1                 87         toyota       gas        std
# 73           2                161     mitsubishi       gas        std
# 31           1                101          honda       gas        std
# 86           1                128         nissan       gas        std
# 115          1                119       plymouth       gas        std
# 20           1                118          dodge       gas        std
# 48           1                104          mazda       gas        std
# 74           2                161     mitsubishi       gas        std
# 23           1                148          dodge       gas        std
# ...

# %% [markdown]
# --------------

# %% [markdown]
# **Q.no(12).Show the prices of the cars in descending order.**

# %%
auto.sort_values(by='price',ascending=0) ## default is ascending order.
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 71           1                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 70           0                140  mercedes-benz       gas        std
# 125          3                128        porsche       gas        std
# 16           0                149            bmw       gas        std
# 46           0                115         jaguar       gas        std
# 45           0                115         jaguar       gas        std
# 69           3                142  mercedes-benz       gas        std
# 68          -1                122  mercedes-benz       gas        std
# 124          3                128        porsche       gas        std
# 123          3                128        porsche       gas        std
# 44           0                145         jaguar       gas        std
# ...

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(12).What is the rank order of the cars as per there horsepower.**

# %%
auto['horse power']=auto['horsepower'].rank(ascending=0)
auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %% [markdown]
# ---------------

# %% [markdown]
# **Q.no(12).What is the rank order of the cars as per there minimum prices.**

# %%
auto['minimum price']=auto['price'].rank(ascending=0,method='min')
auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(13).What is the rank order of the cars as per there maximum prices.**

# %%
auto['maximum price']=auto['price'].rank(ascending=0,method='max')
auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(14).What is the dense rank order of the cars as per there horsepower.**

# %%
auto['denserank HP']=auto['horsepower'].rank(ascending=0,method='dense')
auto
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# 6            1                158         audi       gas        std
# 7            1                168         audi       gas        std
# 8            1                158         audi       gas      turbo
# 9            2                192          bmw       gas        std
# 10           0                192          bmw       gas        std
# 11           0                188          bmw       gas        std
# 12           0                188          bmw       gas        std
# ...

# %%
auto.groupby('make').mean()['price']
# Out:
# make
# alfa-romero       46495
# audi             107155
# bmw              208950
# chevrolet         18021
# dodge             70879
# honda            106401
# isuzu             17833
# jaguar           103800
# mazda            181099
# mercedes-benz    269176
# mercury           16503
# mitsubishi       120117
# nissan           187482
# peugot           170380
# plymouth          55744
# porsche          125602
# renault           19190
# saab              91340
# subaru           102495
# toyota           316346
# volkswagen       120930
# volvo            198695
# Name: price, dtype: int64

# %% [markdown]
# ----------------

# %% [markdown]
# **Q.no(15). Write a code to display the  `make` and `price` of `5,6,10` rows.**

# %%
auto.loc[[5,6,10],['make','price']] #subset of rows and columns using loc function
# Out:
#     make  price
# 5   audi  15250
# 6   audi  17710
# 10   bmw  16925

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(16). Write a code to display the  `first five columns` and  `5 to 10 rows` using as per `index position`.**

# %%
auto.iloc[5:11,0:5]  #select based off of index position instead of label - use iloc instead of loc function
# Out:
#     symboling  normalized_losses  make fuel_type aspiration
# 5           2                161  audi       gas        std
# 6           1                158  audi       gas        std
# 7           1                168  audi       gas        std
# 8           1                158  audi       gas      turbo
# 9           2                192   bmw       gas        std
# 10          0                192   bmw       gas        std

# %% [markdown]
# # ----------------------------------HAPPY LEARNING----------------------------------------

# %% [markdown]
# -------
